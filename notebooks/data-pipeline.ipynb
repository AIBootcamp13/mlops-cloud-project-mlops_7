# %% [markdown]
# # Notebook 기본 세팅

# %%
# Constant 선언

# 프로젝트 루트 디렉토리를 식별하기 위한 마커 파일 이름
ROOT_MARKER = "pyproject.toml"

# 한글 표시를 위한 나눔바른고딕 폰트 파일 이름
# matplotlib 의 font_manager 에 실제 폰트 파일의 위치를 넣어주어야 한다.
KOREAN_FONT_FILE = "NanumBarunGothic.ttf"

# matplotlib 에서는 font-family 의 이름으로 font 를 설정한다.
# 그래서 font 파일 그 자체가 아니라, 그 파일의 family 이름을 적어준다.
KOREAN_FONT_FAMILY = "NanumBarunGothic"

# 참고
# Font Family 와 Font File 의 차이는,
# Font Family 는 비슷한 디자인 특성을 공유하는 글꼴 그룹을 의미한다.
#
# 예를 들어 '나눔바른고딕' 폰트 패밀리는 일반(Regular), 굵게(Bold), 기울임(Italic) 등 여러 스타일을 포함할 수 있다.
# 반면, 폰트 파일(.ttf, .otf 등)은 이러한 폰트의 하나의 스타일이 저장된 실제 파일이다.
#
# 이 프로젝트에서는 폰트 용량을 줄이기 위해 일반(Regular) 인 NanumBarunGothic.ttf 만 사용한다.

# %%
# 프로젝트 root 를 sys.path 에 추가해서 import 구문을 사용하기 쉽게
from pathlib import Path


def find_project_root() -> Path:
    """
    pyproject.toml 파일을 기준으로 루트 디렉토리를 찾는다.
    :return: Path: 프로젝트 루트 디렉토리 경로
    """

    current_path = Path().resolve()

    while current_path != current_path.parent:
        if (current_path / ROOT_MARKER).exists():
            return current_path

        current_path = current_path.parent

    raise FileNotFoundError("프로젝트 루트 디렉토리를 찾을 수 없습니다.")


ROOT_DIR = find_project_root()

# %%
# matplotlib 의 한글 font 설정
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt


FONTS_DATA_DIR = ROOT_DIR / "notebooks" / "fonts"


def setup_korean_font():
    font_path = FONTS_DATA_DIR / KOREAN_FONT_FILE
    fm.fontManager.addfont(font_path)

    # 폰트 설정
    plt.rcParams["font.family"] = KOREAN_FONT_FAMILY
    plt.rcParams["axes.unicode_minus"] = False


setup_korean_font()

# %% [markdown]
# # Data Pipeline Sample

# %%
import pandas as pd

from src.data.loader import AsosDataLoader
from src.libs.storage import Storage


storage = Storage.create()

loader = AsosDataLoader(storage)

# %% [markdown]
# - 종관 지점별 5년치 기상 데이터 가져오기

# %%
df_per_station = loader.load()
# Out:
# [2025-05-30 15:50:25] INFO [src.libs.storage._check_and_log_response] Success to retrieve
# [2025-05-30 15:50:25] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-100-daegwallyeong.csv
# [2025-05-30 15:50:25] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-101-chuncheon.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-102-baengnyeongdo.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-105-gangneung.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-106-donghae.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-108-seoul.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-112-incheon.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-114-wonju.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-115-ulleungdo.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-119-suwon.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-121-yeongwol.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-127-chungju.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-129-seosan.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-130-uljin.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-131-cheongju.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-133-daejeon.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-135-chupungnyeong.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-136-andong.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-137-sangju.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-138-pohang.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-140-gunsan.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-143-daegu.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-146-jeonju.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-152-ulsan.csv
# [2025-05-30 15:50:26] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-155-changwon.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-156-gwangju.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-159-busan.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-162-tongyeong.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-165-mokpo.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-168-yeosu.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-169-heuksando.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-170-wando.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-172-gochang.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-174-suncheon.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-177-hongseong.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-184-jeju.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-185-gosan.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-188-seongsan.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-189-seogwipo.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-192-jinju.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-201-ganghwa.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-202-yangpyeong.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-203-icheon.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-211-inje.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-212-hongcheon.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-216-taebaek.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-217-jeongseon.csv
# [2025-05-30 15:50:27] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-221-jecheon.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-226-boeun.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-232-cheonan.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-235-boryeong.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-236-buyeo.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-238-geumsan.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-239-sejong.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-243-buan.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-244-imsil.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-245-jeongeup.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-247-namwon.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-248-jangsu.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-252-yeonggwang.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-253-gimhae.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-254-sunchang.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-257-yangsan.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-258-boseong.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-259-gangjin.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-260-jangheung.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-261-haenam.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-262-goheung.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-263-uiryeong.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-264-hamyang.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-266-gwangyang.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-268-jindo.csv
# [2025-05-30 15:50:28] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-271-bonghwa.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-272-yeongju.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-273-mungyeong.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-276-cheongsong.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-277-yeongdeok.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-278-uiseong.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-279-gumi.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-281-yeongcheon.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-283-gyeongju.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-284-geochang.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-285-hapcheon.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-288-miryang.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-289-sancheong.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-294-geoje.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-295-namhae.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-90-sokcho.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-95-cheorwon.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-98-dongducheon.csv
# [2025-05-30 15:50:29] INFO [src.libs.storage._check_and_log_response] Success to read datasets/20200527-20250527-99-paju.csv

# %% [markdown]
# - 지점별 데이터를 한 개의 DataFrame 로 병합하기

# %%
total_df = pd.concat(list(df_per_station.values()))
total_df
# Out:
#       stn_id stn_nm          tm  avg_ta  min_ta  min_ta_hrmt  max_ta  \
# 0        100    대관령  2020-05-27    13.4     8.0        529.0    19.2
# 1        100    대관령  2020-05-28    12.3     7.0        243.0    19.4
# 2        100    대관령  2020-05-29    12.6     4.4        550.0    19.9
# 3        100    대관령  2020-05-30    14.1     4.0        503.0    22.8
# 4        100    대관령  2020-05-31    16.5     5.6        453.0    22.3
# ...      ...    ...         ...     ...     ...          ...     ...
# 1822      99     파주  2025-05-23    16.5    13.6       2346.0    21.9
# 1823      99     파주  2025-05-24    14.8     9.6       2333.0    19.5
# 1824      99     파주  2025-05-25    15.5     7.6        520.0    22.3
# 1825      99     파주  2025-05-26    16.7     9.0        526.0    25.3
# 1826      99     파주  2025-05-27    17.9    10.2        524.0    25.8
#
#       max_ta_hrmt  sum_rn_dur  mi10_max_rn  ...  avg_m05_te  avg_m10_te  \
# 0          1332.0         NaN          0.1  ...         NaN         NaN
# 1          1144.0         NaN          0.0  ...         NaN         NaN
# 2          1207.0         NaN          NaN  ...         NaN         NaN
# 3          1426.0         NaN          NaN  ...         NaN         NaN
# 4          1058.0         NaN          NaN  ...         NaN         NaN
# ...           ...         ...          ...  ...         ...         ...
# 1822       1425.0         NaN          0.5  ...         NaN         NaN
# 1823       1248.0         NaN          0.1  ...         NaN         NaN
# 1824       1533.0         NaN          NaN  ...         NaN         NaN
# 1825       1501.0         NaN          NaN  ...         NaN         NaN
# 1826       1443.0         NaN          NaN  ...         NaN         NaN
#
#       avg_m15_te  avg_m30_te  avg_m50_te  sum_lrg_ev  sum_sml_ev  n99_rn  \
# 0            NaN         NaN         NaN         3.8         5.4     NaN
# 1            NaN         NaN         NaN         3.4         4.8     NaN
# 2            NaN         NaN         NaN         4.7         6.7     NaN
# 3            NaN         NaN         NaN         5.7         8.2     NaN
# 4            NaN         NaN         NaN         4.4         6.3     NaN
# ...          ...         ...         ...         ...         ...     ...
# 1822         NaN         NaN         NaN         1.7         2.4     NaN
# 1823         NaN         NaN         NaN         2.7         3.8     NaN
# 1824         NaN         NaN         NaN         4.2         6.1     NaN
# 1825         NaN         NaN         NaN         4.2         6.0     NaN
# 1826         NaN         NaN         NaN         4.2         5.9     NaN
#
#       iscs  sum_fog_dur
# 0      NaN          NaN
# 1      NaN          NaN
# 2      NaN          NaN
# 3      NaN          NaN
# 4      NaN          NaN
# ...    ...          ...
# 1822   NaN          NaN
# 1823   NaN          NaN
# 1824   NaN          NaN
# 1825   NaN          NaN
# 1826   NaN          NaN
#
# [166247 rows x 62 columns]

# %% [markdown]
# - 결측치 처리기

# %%
from src.data.imputer import WeatherDataImputer


imputer = WeatherDataImputer()

# %%
transformed_df = imputer.transform(total_df)
transformed_df
# Out:
#       stn_id stn_nm          tm  avg_ta  min_ta  min_ta_hrmt  max_ta  \
# 0        100    대관령  2020-05-27    19.8    15.3        529.0    25.7
# 1        100    대관령  2020-05-28    20.2    14.0        243.0    25.9
# 2        100    대관령  2020-05-29    20.1    15.1        550.0    26.6
# 3        100    대관령  2020-05-30    19.8    16.2        503.0    24.0
# 4        100    대관령  2020-05-31    18.9    15.5        453.0    22.9
# ...      ...    ...         ...     ...     ...          ...     ...
# 1822      99     파주  2025-05-23    18.4    16.0       2346.0    21.2
# 1823      99     파주  2025-05-24    15.4    14.2       2333.0    18.6
# 1824      99     파주  2025-05-25    16.9    13.8        520.0    22.3
# 1825      99     파주  2025-05-26    17.6    13.5        526.0    23.4
# 1826      99     파주  2025-05-27    18.7    13.1        524.0    25.3
#
#       max_ta_hrmt  mi10_max_rn  mi10_max_rn_hrmt  ...  max_ps_hrmt  min_ps  \
# 0          1332.0          0.1               0.0  ...       2359.0  1004.9
# 1          1144.0          0.0               0.0  ...       2340.0  1006.7
# 2          1207.0          0.0               0.0  ...       2338.0  1013.4
# 3          1426.0          0.0               0.0  ...        502.0  1013.8
# 4          1058.0          0.0               0.0  ...         15.0  1006.7
# ...           ...          ...               ...  ...          ...     ...
# 1822       1425.0          0.5            1700.0  ...       2242.0  1009.7
# 1823       1248.0          0.1               0.0  ...       2339.0  1009.5
# 1824       1533.0          0.0               0.0  ...       2243.0  1013.3
# 1825       1501.0          0.0               0.0  ...        835.0  1016.0
# 1826       1443.0          0.0               0.0  ...        745.0  1016.6
#
#       min_ps_hrmt  avg_ps  ss_dur  sum_ss_hr  avg_tca  avg_lmac  avg_ts  \
# 0          1722.0  1008.3    14.3       11.2      5.8       0.1    24.9
# 1          1255.0  1009.1    14.3       12.6      1.8       0.4    26.1
# 2           949.0  1014.7    14.3       12.3      4.9       0.3    26.6
# 3          1553.0  1017.1    14.3        0.5      9.8       0.8    23.3
# 4          1730.0  1012.4    14.3        0.7      7.6       6.0    22.6
# ...           ...     ...     ...        ...      ...       ...     ...
# 1822         58.0  1011.6    14.2        1.1      9.6       7.0    21.0
# 1823       1556.0  1008.4    14.2        0.6      9.6       4.8    16.5
# 1824          2.0  1014.6    14.2       10.6      3.5       2.6    24.2
# 1825       1653.0  1018.2    14.2        8.8      2.9       1.1    24.6
# 1826       1638.0  1018.7    14.3       11.7      0.0       0.0    26.7
#
#       min_tg
# 0        4.9
# 1        3.2
# 2        0.6
# 3        0.6
# 4        2.5
# ...      ...
# 1822    14.0
# 1823     9.8
# 1824     8.0
# 1825     9.5
# 1826     9.9
#
# [166247 rows x 39 columns]

# %% [markdown]
# - 날시 label(맑음, 흐림, 비, 눈) 을 추가

# %%
from src.data.labeler import WeatherLabeler


transformed_df["weather"] = transformed_df.apply(
    lambda row: WeatherLabeler(row).determine_weather_label().value, axis=1
)
