# %% [markdown]
# # Notebook 기본 세팅

# %%
# Constant 선언

# 프로젝트 루트 디렉토리를 식별하기 위한 마커 파일 이름
ROOT_MARKER = "pyproject.toml"

# 한글 표시를 위한 나눔바른고딕 폰트 파일 이름
# matplotlib 의 font_manager 에 실제 폰트 파일의 위치를 넣어주어야 한다.
KOREAN_FONT_FILE = "NanumBarunGothic.ttf"

# matplotlib 에서는 font-family 의 이름으로 font 를 설정한다.
# 그래서 font 파일 그 자체가 아니라, 그 파일의 family 이름을 적어준다.
KOREAN_FONT_FAMILY = "NanumBarunGothic"

# 참고
# Font Family 와 Font File 의 차이는,
# Font Family 는 비슷한 디자인 특성을 공유하는 글꼴 그룹을 의미한다.
#
# 예를 들어 '나눔바른고딕' 폰트 패밀리는 일반(Regular), 굵게(Bold), 기울임(Italic) 등 여러 스타일을 포함할 수 있다.
# 반면, 폰트 파일(.ttf, .otf 등)은 이러한 폰트의 하나의 스타일이 저장된 실제 파일이다.
#
# 이 프로젝트에서는 폰트 용량을 줄이기 위해 일반(Regular) 인 NanumBarunGothic.ttf 만 사용한다.

# %%
# 프로젝트 root 를 sys.path 에 추가해서 import 구문을 사용하기 쉽게
from pathlib import Path


def find_project_root() -> Path:
    """
    pyproject.toml 파일을 기준으로 루트 디렉토리를 찾는다.
    :return: Path: 프로젝트 루트 디렉토리 경로
    """

    current_path = Path().resolve()

    while current_path != current_path.parent:
        if (current_path / ROOT_MARKER).exists():
            return current_path

        current_path = current_path.parent

    raise FileNotFoundError("프로젝트 루트 디렉토리를 찾을 수 없습니다.")


ROOT_DIR = find_project_root()

# %%
# matplotlib 의 한글 font 설정
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt


FONTS_DATA_DIR = ROOT_DIR / "notebooks" / "fonts"


def setup_korean_font():
    font_path = FONTS_DATA_DIR / KOREAN_FONT_FILE
    fm.fontManager.addfont(font_path)

    # 폰트 설정
    plt.rcParams["font.family"] = KOREAN_FONT_FAMILY
    plt.rcParams["axes.unicode_minus"] = False


setup_korean_font()

# %% [markdown]
# ## Naver Cloud Storage 연동해보기

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
pip install boto3
# Out:
# Requirement already satisfied: boto3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.38.24)
# Requirement already satisfied: botocore<1.39.0,>=1.38.24 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from boto3) (1.38.24)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from boto3) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/gominju/Library/Python/3.13/lib/python/site-packages (from botocore<1.39.0,>=1.38.24->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from botocore<1.39.0,>=1.38.24->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /Users/gominju/Library/Python/3.13/lib/python/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.24->boto3) (1.17.0)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

#환경변수 키 가져오기
NCLOUD_ACCESS_KEY = os.getenv("NCLOUD_ACCESS_KEY")
NCLOUD_SECRET_KEY = os.getenv("NCLOUD_SECRET_KEY")
NCLOUD_STORAGE_REGION = os.getenv("NCLOUD_STORAGE_REGION")
NCLOUD_STORAGE_BUCKET = os.getenv("NCLOUD_STORAGE_BUCKET")
NCLOUD_STORAGE_ENDPOINT_URL = os.getenv("NCLOUD_STORAGE_ENDPOINT_URL")

#S3 클라이언트 생성

# %%
import boto3
from botocore.client import Config

s3_client = boto3.client(
    "s3",
    endpoint_url=NCLOUD_STORAGE_ENDPOINT_URL,
    aws_access_key_id=NCLOUD_ACCESS_KEY,
    aws_secret_access_key=NCLOUD_SECRET_KEY,
    region_name=NCLOUD_STORAGE_REGION,
    config=Config(signature_version="s3v4"),
)

# %%
from io import StringIO

import pandas as pd


DATASETS_DIR = "datasets"


def upload_dataframe_as_csv(df: pd.DataFrame, index: bool = False):
    csv_buffer = StringIO()
    df.to_csv(csv_buffer, index=index)
    return s3_client.put_object(
        Bucket=NCLOUD_STORAGE_BUCKET,
        Key=f"{DATASETS_DIR}/data.csv",
        Body=csv_buffer.getvalue(),
    )

# %%
example_df = pd.DataFrame({"name": ["tom", "jane", "elly"], "gender": ["m", "f", "f"], "age": [21, 23, 34]})
example_df
# Out:
#    name gender  age
# 0   tom      m   21
# 1  jane      f   23
# 2  elly      f   34

# %%
upload_dataframe_as_csv(example_df)
# Out:
# {'ResponseMetadata': {'RequestId': '0111b12a-126f-492b-82b5-de15d6abf8b8',
#   'HostId': 'Yzk0YmI0YmM5NGJlMjQ4N2RmNTRmYTM2OGNhNTE0NGZjNjMzNmEzYWI4NDZiMGRhMTVjNDFhYjM5NDg3YzcyZg==',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'etag': '"84a182d4f332cf1fd04213ecd3c9263e"',
#    'x-amz-checksum-crc32': 'jeoaSw==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'Yzk0YmI0YmM5NGJlMjQ4N2RmNTRmYTM2OGNhNTE0NGZjNjMzNmEzYWI4NDZiMGRhMTVjNDFhYjM5NDg3YzcyZg==',
#    'x-amz-request-id': '0111b12a-126f-492b-82b5-de15d6abf8b8',
#    'x-amz-version-id': '922a071a-3c16-11f0-b92f-9cc2c468d112',
#    'date': 'Wed, 28 May 2025 22:53:28 GMT',
#    'content-length': '0',
#    'server': 'Ncloud Storage'},
#   'RetryAttempts': 0},
#  'ETag': '"84a182d4f332cf1fd04213ecd3c9263e"',
#  'ChecksumCRC32': 'jeoaSw==',
#  'ChecksumType': 'FULL_OBJECT',
#  'VersionId': '922a071a-3c16-11f0-b92f-9cc2c468d112'}

# %%
def read_csv_as_dataframe(key: str) -> pd.DataFrame:
    r = s3_client.get_object(Bucket=NCLOUD_STORAGE_BUCKET, Key=key)
    file_content = r["Body"].read().decode("utf-8")
    csv_buffer = StringIO(file_content)
    return pd.read_csv(csv_buffer)

# %%
read_csv_as_dataframe(f"{DATASETS_DIR}/data.csv")
# Out:
#    name gender  age
# 0   tom      m   21
# 1  jane      f   23
# 2  elly      f   34

# %%
s3_client.delete_object(Bucket=NCLOUD_STORAGE_BUCKET, Key=f"{DATASETS_DIR}/data.csv")
# Out:
# {'ResponseMetadata': {'RequestId': '5ada3802-e94d-4f7e-85b7-c35cfa9dab73',
#   'HostId': 'Yzk0YmI0YmM5NGJlMjQ4N2RmNTRmYTM2OGNhNTE0NGZjNjMzNmEzYWI4NDZiMGRhMTVjNDFhYjM5NDg3YzcyZg==',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-delete-marker': 'true',
#    'x-amz-id-2': 'Yzk0YmI0YmM5NGJlMjQ4N2RmNTRmYTM2OGNhNTE0NGZjNjMzNmEzYWI4NDZiMGRhMTVjNDFhYjM5NDg3YzcyZg==',
#    'x-amz-request-id': '5ada3802-e94d-4f7e-85b7-c35cfa9dab73',
#    'x-amz-version-id': 'a3076700-3c16-11f0-b92f-9cc2c468d112',
#    'date': 'Wed, 28 May 2025 22:53:57 GMT',
#    'server': 'Ncloud Storage'},
#   'RetryAttempts': 0},
#  'DeleteMarker': True,
#  'VersionId': 'a3076700-3c16-11f0-b92f-9cc2c468d112'}

# %% [markdown]
# ### -> 추후 container 안에서 연동 코드 작성 및 실행해야함

# %% [markdown]
# ### 기상청 데이터 수집

# %%
import requests
import pandas as pd

#총 96개 지점
stn_ids = [
    "90", "93", "95", "98", "99", "100", "101", "102", "104", "105",
    "106", "108", "112", "114", "115", "119", "121", "127", "129", "130",
    "131", "133", "135", "136", "137", "138", "140", "143", "146", "152",
    "155", "156", "159", "162", "165", "168", "169", "170", "172", "174",
    "177", "184", "185", "188", "189", "192", "201", "202", "203", "211",
    "212", "216", "217", "221", "226", "232", "235", "236", "238", "239",
    "243", "244", "245", "247", "248", "251", "252", "253", "254", "255",
    "257", "258", "259", "260", "261", "262", "263", "264", "266", "268",
    "271", "272", "273", "276", "277", "278", "279", "281", "283", "284",
    "285", "288", "289", "294", "295"
]

years = [
    ("20200101", "20201231"),  # 2020년
    ("20210101", "20211231"),  # 2021년  
    ("20220101", "20221231"),  # 2022년
    ("20230101", "20231231"),  # 2023년
    ("20240101", "20241231")   # 2024년
]

url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList"

dfs = []
for start_dt, end_dt in years:
    for stn_id in stn_ids:
        params = {
            "serviceKey": WEATHER_API_KEY,
            "pageNo": "1",
            "numOfRows": "999",
            "dataType": "JSON",
            "dataCd": "ASOS",
            "dateCd": "DAY",
            "startDt": start_dt,
            "endDt": end_dt,
            "stnIds": stn_id
        }
        
        try:
            res = requests.get(url, params=params)
            
            # 응답 상태 먼저 확인
            print(f"지점 {stn_id}, {start_dt[:4]}년 - Status: {res.status_code}")
            
            if res.status_code != 200:
                print(f"❌ HTTP 에러: {res.status_code}")
                continue
                
            # 응답 내용 확인
            if not res.text.strip():
                print(f"❌ 빈 응답")
                continue
                
            response = res.json()
            items = response["response"]["body"]["items"]["item"]
            
        except requests.exceptions.JSONDecodeError as e:
            print(f"🚨 JSON 에러 발생!")
            print(f"   지점: {stn_id}")
            print(f"   기간: {start_dt}-{end_dt}")
            print(f"   응답: {res.text[:200]}")  # 처음 200자만
            print("-" * 50)
            continue  # 다음으로 넘어가기
# Out:
# 지점 90, 2020년 - Status: 200
# 지점 93, 2020년 - Status: 200
# 지점 95, 2020년 - Status: 200
# 지점 98, 2020년 - Status: 200
# 지점 99, 2020년 - Status: 200
# 지점 100, 2020년 - Status: 200
# 지점 101, 2020년 - Status: 200
# 지점 102, 2020년 - Status: 200
# 지점 104, 2020년 - Status: 200
# 지점 105, 2020년 - Status: 200
# 지점 106, 2020년 - Status: 200
# 지점 108, 2020년 - Status: 200
# 🚨 JSON 에러 발생!
#    지점: 108
#    기간: 20200101-20201231
#    응답: <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP ROUTING ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_Serv
# --------------------------------------------------
# 지점 112, 2020년 - Status: 200
# 지점 114, 2020년 - Status: 200
# 지점 115, 2020년 - Status: 200
# 지점 119, 2020년 - Status: 200
# 지점 121, 2020년 - Status: 200
# 지점 127, 2020년 - Status: 200
# 지점 129, 2020년 - Status: 200
# 지점 130, 2020년 - Status: 200
# 지점 131, 2020년 - Status: 200
# 지점 133, 2020년 - Status: 200
# 지점 135, 2020년 - Status: 200
# 지점 136, 2020년 - Status: 200
# 지점 137, 2020년 - Status: 200
# 🚨 JSON 에러 발생!
#    지점: 137
#    기간: 20200101-20201231
#    응답: <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP ROUTING ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_Serv
# --------------------------------------------------
# 지점 138, 2020년 - Status: 200
# 지점 140, 2020년 - Status: 200
# 지점 143, 2020년 - Status: 200
# 지점 146, 2020년 - Status: 200
# 지점 152, 2020년 - Status: 200
# 지점 155, 2020년 - Status: 200
# 지점 156, 2020년 - Status: 200
# 지점 159, 2020년 - Status: 200
# 지점 162, 2020년 - Status: 200
# 지점 165, 2020년 - Status: 200
# 지점 168, 2020년 - Status: 200
# 지점 169, 2020년 - Status: 200
# 지점 170, 2020년 - Status: 200
# 지점 172, 2020년 - Status: 200
# 지점 174, 2020년 - Status: 200
# 지점 177, 2020년 - Status: 200
# 지점 184, 2020년 - Status: 200
# 지점 185, 2020년 - Status: 200
# 지점 188, 2020년 - Status: 200
# 지점 189, 2020년 - Status: 200
# 지점 192, 2020년 - Status: 200
# 지점 201, 2020년 - Status: 200
# 지점 202, 2020년 - Status: 200
# 지점 203, 2020년 - Status: 200
# 지점 211, 2020년 - Status: 200
# 지점 212, 2020년 - Status: 200
# 지점 216, 2020년 - Status: 200
# 지점 217, 2020년 - Status: 200
# 지점 221, 2020년 - Status: 200
# 지점 226, 2020년 - Status: 200
# 지점 232, 2020년 - Status: 200
# 지점 235, 2020년 - Status: 200
# 지점 236, 2020년 - Status: 200
# 지점 238, 2020년 - Status: 200
# 지점 239, 2020년 - Status: 200
# 지점 243, 2020년 - Status: 200
# 지점 244, 2020년 - Status: 200
# 지점 245, 2020년 - Status: 200
# 지점 247, 2020년 - Status: 200
# 지점 248, 2020년 - Status: 200
# 지점 251, 2020년 - Status: 200
# 지점 252, 2020년 - Status: 200
# 지점 253, 2020년 - Status: 200
# 지점 254, 2020년 - Status: 200
# 지점 255, 2020년 - Status: 200
# 지점 257, 2020년 - Status: 200
# 지점 258, 2020년 - Status: 200
# 지점 259, 2020년 - Status: 200
# 지점 192, 2022년 - Status: 200
# 지점 201, 2022년 - Status: 200
# 지점 202, 2022년 - Status: 200
# 지점 203, 2022년 - Status: 200
# 지점 211, 2022년 - Status: 200
# 지점 212, 2022년 - Status: 200
# 지점 216, 2022년 - Status: 200
# 지점 217, 2022년 - Status: 200
# 지점 221, 2022년 - Status: 200
# 지점 226, 2022년 - Status: 200
# 지점 232, 2022년 - Status: 200
# 지점 235, 2022년 - Status: 200
# 지점 236, 2022년 - Status: 200
# 지점 238, 2022년 - Status: 200
# 지점 239, 2022년 - Status: 200
# 지점 243, 2022년 - Status: 200
# 지점 244, 2022년 - Status: 200
# 지점 245, 2022년 - Status: 200
# 지점 247, 2022년 - Status: 200
# 지점 248, 2022년 - Status: 200
# 지점 251, 2022년 - Status: 200
# 지점 252, 2022년 - Status: 200
# 지점 253, 2022년 - Status: 200
# 지점 254, 2022년 - Status: 200
# 지점 255, 2022년 - Status: 200
# 지점 257, 2022년 - Status: 200
# 지점 258, 2022년 - Status: 200
# 지점 259, 2022년 - Status: 200
# 지점 260, 2022년 - Status: 200
# 지점 261, 2022년 - Status: 200
# 지점 262, 2022년 - Status: 200
# 지점 263, 2022년 - Status: 200
# 지점 264, 2022년 - Status: 200
# 지점 266, 2022년 - Status: 200
# 지점 268, 2022년 - Status: 200
# 지점 271, 2022년 - Status: 200
# 지점 272, 2022년 - Status: 200
# 지점 273, 2022년 - Status: 200
# 지점 276, 2022년 - Status: 200
# 지점 277, 2022년 - Status: 200
# 지점 278, 2022년 - Status: 200
# 지점 279, 2022년 - Status: 200
# 지점 281, 2022년 - Status: 200
# 지점 283, 2022년 - Status: 200
# 지점 284, 2022년 - Status: 200
# 지점 285, 2022년 - Status: 200
# 지점 288, 2022년 - Status: 200
# 지점 289, 2022년 - Status: 200
# 지점 294, 2022년 - Status: 200
# 지점 295, 2022년 - Status: 200
# 지점 90, 2023년 - Status: 200
# 지점 93, 2023년 - Status: 200
# 지점 95, 2023년 - Status: 200
# 지점 98, 2023년 - Status: 200
# 지점 99, 2023년 - Status: 200
# 지점 100, 2023년 - Status: 200
# 지점 101, 2023년 - Status: 200
# 지점 102, 2023년 - Status: 200
# 지점 104, 2023년 - Status: 200
# 지점 105, 2023년 - Status: 200
# 지점 106, 2023년 - Status: 200
# 지점 108, 2023년 - Status: 200
# 지점 112, 2023년 - Status: 200
# 지점 114, 2023년 - Status: 200
# 지점 115, 2023년 - Status: 200
# 🚨 JSON 에러 발생!
#    지점: 115
#    기간: 20230101-20231231
#    응답: <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP ROUTING ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_Serv
# --------------------------------------------------
# 지점 119, 2023년 - Status: 200
# 지점 121, 2023년 - Status: 200
# 지점 127, 2023년 - Status: 200
# 지점 129, 2023년 - Status: 200
# 지점 130, 2023년 - Status: 200
# 지점 131, 2023년 - Status: 200
# 지점 133, 2023년 - Status: 200
# 지점 135, 2023년 - Status: 200
# 지점 136, 2023년 - Status: 200
# 지점 137, 2023년 - Status: 200
# 지점 138, 2023년 - Status: 200
# 지점 140, 2023년 - Status: 200
# 지점 143, 2023년 - Status: 200
# 지점 146, 2023년 - Status: 200
# 지점 152, 2023년 - Status: 200
# 지점 155, 2023년 - Status: 200
# 지점 156, 2023년 - Status: 200
# 지점 159, 2023년 - Status: 200
# 지점 162, 2023년 - Status: 200
# 지점 165, 2023년 - Status: 200
# 지점 168, 2023년 - Status: 200
# 지점 169, 2023년 - Status: 200
# 지점 170, 2023년 - Status: 200
# 지점 172, 2023년 - Status: 200
# 지점 174, 2023년 - Status: 200
# 🚨 JSON 에러 발생!
#    지점: 174
#    기간: 20230101-20231231
#    응답: <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP ROUTING ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_Serv
# --------------------------------------------------
# 지점 177, 2023년 - Status: 200
# 지점 184, 2023년 - Status: 200
# 지점 185, 2023년 - Status: 200
# 지점 188, 2023년 - Status: 200
# 지점 189, 2023년 - Status: 200
# 지점 192, 2023년 - Status: 200
# 지점 201, 2023년 - Status: 200
# 지점 202, 2023년 - Status: 200
# 지점 203, 2023년 - Status: 200
# 지점 211, 2023년 - Status: 200
# 지점 212, 2023년 - Status: 200
# 지점 216, 2023년 - Status: 200
# 지점 217, 2023년 - Status: 200
# 지점 221, 2023년 - Status: 200
# 지점 226, 2023년 - Status: 200
# 지점 232, 2023년 - Status: 200
# 지점 235, 2023년 - Status: 200
# 지점 236, 2023년 - Status: 200
# 지점 238, 2023년 - Status: 200
# 지점 239, 2023년 - Status: 200
# 지점 243, 2023년 - Status: 200
# 지점 244, 2023년 - Status: 200
# 지점 245, 2023년 - Status: 200
# 지점 247, 2023년 - Status: 200
# 지점 248, 2023년 - Status: 200
# 지점 251, 2023년 - Status: 200
# 지점 252, 2023년 - Status: 200
# 지점 253, 2023년 - Status: 200
# 지점 254, 2023년 - Status: 200
# 지점 255, 2023년 - Status: 200
# 지점 257, 2023년 - Status: 200
# 지점 258, 2023년 - Status: 200
# 지점 259, 2023년 - Status: 200
# 지점 260, 2023년 - Status: 200
# 지점 261, 2023년 - Status: 200
# 지점 262, 2023년 - Status: 200
# 지점 263, 2023년 - Status: 200
# 지점 264, 2023년 - Status: 200
# 지점 266, 2023년 - Status: 200
# 지점 268, 2023년 - Status: 200
# 지점 271, 2023년 - Status: 200
# 지점 272, 2023년 - Status: 200
# 지점 273, 2023년 - Status: 200
# 지점 276, 2023년 - Status: 200
# 지점 277, 2023년 - Status: 200
# 지점 278, 2023년 - Status: 200
# 지점 279, 2023년 - Status: 200
# 지점 281, 2023년 - Status: 200
# 지점 283, 2023년 - Status: 200
# 지점 284, 2023년 - Status: 200
# 지점 285, 2023년 - Status: 200
# 지점 288, 2023년 - Status: 200
# 지점 266, 2024년 - Status: 200
# 지점 268, 2024년 - Status: 200
# 지점 271, 2024년 - Status: 200
# 지점 272, 2024년 - Status: 200
# 지점 273, 2024년 - Status: 200
# 지점 276, 2024년 - Status: 200
# 지점 277, 2024년 - Status: 200
# 지점 278, 2024년 - Status: 200
# 지점 279, 2024년 - Status: 200
# 지점 281, 2024년 - Status: 200
# 지점 283, 2024년 - Status: 200
# 지점 284, 2024년 - Status: 200
# 지점 285, 2024년 - Status: 200
# 지점 288, 2024년 - Status: 200
# 지점 289, 2024년 - Status: 200
# 지점 294, 2024년 - Status: 200
# 지점 295, 2024년 - Status: 200

# %%
import requests
import pandas as pd

#총 96개 지점
stn_ids = [
    "90", "93", "95", "98", "99", "100", "101", "102", "104", "105",
    "106", "108", "112", "114", "115", "119", "121", "127", "129", "130",
    "131", "133", "135", "136", "137", "138", "140", "143", "146", "152",
    "155", "156", "159", "162", "165", "168", "169", "170", "172", "174",
    "177", "184", "185", "188", "189", "192", "201", "202", "203", "211",
    "212", "216", "217", "221", "226", "232", "235", "236", "238", "239",
    "243", "244", "245", "247", "248", "251", "252", "253", "254", "255",
    "257", "258", "259", "260", "261", "262", "263", "264", "266", "268",
    "271", "272", "273", "276", "277", "278", "279", "281", "283", "284",
    "285", "288", "289", "294", "295"
]

years = [
    ("20200101", "20201231"),  # 2020년
    ("20210101", "20211231"),  # 2021년  
    ("20220101", "20221231"),  # 2022년
    ("20230101", "20231231"),  # 2023년
    ("20240101", "20241231")   # 2024년
]

url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList"

dfs = []
for start_dt, end_dt in years:
    for stn_id in stn_ids:
        params = {
            "serviceKey": WEATHER_API_KEY,
            "pageNo": "1",
            "numOfRows": "999",
            "dataType": "JSON",
            "dataCd": "ASOS",
            "dateCd": "DAY",
            "startDt": start_dt,
            "endDt": end_dt,
            "stnIds": stn_id
        }

        res = requests.get(url, params=params)
        response = res.json()
        items = response["response"]["body"]["items"]["item"]
        dfs.append(pd.DataFrame(items))
        print(f"{start_dt}-{end_dt} 지점{stn_id}: {len(items)}건")

df = pd.concat(dfs, ignore_index=True)
df.to_csv("weather_96stations_5years.csv", index=False)
print(f"수집 완료: {len(df)}건")
# Out:
# 20200101-20201231 지점90: 366건
# 20200101-20201231 지점93: 366건
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 45
#      32 params = {
#      33     "serviceKey": WEATHER_API_KEY,
#      34     "pageNo": "1",
#    (...)     41     "stnIds": stn_id
#      42 }
#      44 res = requests.get(url, params=params)
# ---> 45 response = res.json()
#      46 items = response["response"]["body"]["items"]["item"]
#      47 dfs.append(pd.DataFrame(items))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
response = res.json()
response
# Out:
# {'response': {'header': {'resultCode': '99',
#    'resultMsg': '데이터요청은 한번에 최대 1,000건을 넘을 수 없습니다.'}}}

# %%
item = response["response"]["body"]["items"]["item"][1]
print(item)
print(type(item))
# Out:
# {'stnId': '108', 'stnNm': '서울', 'tm': '2024-01-02', 'avgTa': '2.9', 'minTa': '2.2', 'minTaHrmt': '0622', 'maxTa': '4.3', 'maxTaHrmt': '1409', 'mi10MaxRn': '', 'mi10MaxRnHrmt': '', 'hr1MaxRn': '', 'hr1MaxRnHrmt': '', 'sumRnDur': '1.58', 'sumRn': '0.0', 'maxInsWs': '5.3', 'maxInsWsWd': '250', 'maxInsWsHrmt': '1407', 'maxWs': '3.1', 'maxWsWd': '270', 'maxWsHrmt': '1409', 'avgWs': '1.6', 'hr24SumRws': '1360', 'maxWd': '290', 'avgTd': '-1.6', 'minRhm': '59', 'minRhmHrmt': '1552', 'avgRhm': '72.6', 'avgPv': '5.5', 'avgPa': '1011.4', 'maxPs': '1024.9', 'maxPsHrmt': '0001', 'minPs': '1020.3', 'minPsHrmt': '2354', 'avgPs': '1022.1', 'ssDur': '9.6', 'sumSsHr': '0.3', 'hr1MaxIcsrHrmt': '1200', 'hr1MaxIcsr': '0.63', 'sumGsr': '3.87', 'ddMefs': '', 'ddMefsHrmt': '', 'ddMes': '', 'ddMesHrmt': '', 'sumDpthFhsc': '', 'avgTca': '8.9', 'avgLmac': '7.4', 'avgTs': '0.3', 'minTg': '-3.3', 'avgCm5Te': '0.0', 'avgCm10Te': '-0.2', 'avgCm20Te': '0.1', 'avgCm30Te': '1.0', 'avgM05Te': '2.8', 'avgM10Te': '6.1', 'avgM15Te': '9.7', 'avgM30Te': '15.6', 'avgM50Te': '18.0', 'sumLrgEv': '0.7', 'sumSmlEv': '1.0', 'n99Rn': '0.1', 'iscs': '-{비}-0105. -{박무}-{박무}{강도0}0300-{박무}{강도0}0600-0810. {비}0720-0750. {연무}1125-{연무}{강도0}1200-1225.', 'sumFogDur': ''}
# <class 'dict'>

# %%
items = response["response"]["body"]["items"]["item"]
print(items)
# Out:
# [{'stnId': '108', 'stnNm': '서울', 'tm': '2024-01-01', 'avgTa': '3.3', 'minTa': '-0.3', 'minTaHrmt': '0402', 'maxTa': '7.3', 'maxTaHrmt': '1255', 'mi10MaxRn': '', 'mi10MaxRnHrmt': '', 'hr1MaxRn': '', 'hr1MaxRnHrmt': '', 'sumRnDur': '2.92', 'sumRn': '0.0', 'maxInsWs': '4.5', 'maxInsWsWd': '180', 'maxInsWsHrmt': '1518', 'maxWs': '3.2', 'maxWsWd': '180', 'maxWsHrmt': '1525', 'avgWs': '1.7', 'hr24SumRws': '1435', 'maxWd': '70', 'avgTd': '0.5', 'minRhm': '65', 'minRhmHrmt': '1312', 'avgRhm': '83.4', 'avgPv': '6.3', 'avgPa': '1016.1', 'maxPs': '1029.4', 'maxPsHrmt': '0934', 'minPs': '1024.8', 'minPsHrmt': '2351', 'avgPs': '1026.9', 'ssDur': '9.6', 'sumSsHr': '4.3', 'hr1MaxIcsrHrmt': '1200', 'hr1MaxIcsr': '1.87', 'sumGsr': '7.44', 'ddMefs': '', 'ddMefsHrmt': '', 'ddMes': '2.4', 'ddMesHrmt': '0001', 'sumDpthFhsc': '', 'avgTca': '6.4', 'avgLmac': '5.8', 'avgTs': '-0.2', 'minTg': '-4.7', 'avgCm5Te': '-0.1', 'avgCm10Te': '-0.2', 'avgCm20Te': '0.1', 'avgCm30Te': '1.0', 'avgM05Te': '2.8', 'avgM10Te': '6.3', 'avgM15Te': '9.9', 'avgM30Te': '15.7', 'avgM50Te': '18.1', 'sumLrgEv': '0.9', 'sumSmlEv': '1.3', 'n99Rn': '0.0', 'iscs': '-{박무}-{박무}{강도1}0300-{박무}{강도1}0600-{박무}{강도0}0900-0925. {비}2045-2055. {비}2115-{비}{강도0}2400- {박무}2135-{박무}{강도0}2400-', 'sumFogDur': ''}, {'stnId': '108', 'stnNm': '서울', 'tm': '
0', 'avgM05Te': '2.8', 'avgM10Te': '6.0', 'avgM15Te': '9.6', 'avgM30Te': '15.5', 'avgM50Te': '18.0', 'sumLrgEv': '0.5', 'sumSmlEv': '0.7', 'n99Rn': '0.5', 'iscs': '{비}0605-{비}{강도0}0900-{싸락눈}0915-{비}0950-1010. {박무}0755-{박무}{강도0}0900-{박무}{강도0}1200-{박무}{강도0}1500-1510. {비}1240-1450. {박무}1705-{박무}{강도0}1800-2015. {박무}2135-{박무}{강도0}2400-', 'sumFogDur': ''}, {'stnId': '108', 'stnNm': '서울', 'tm': '2024-01-04', 'avgTa': '1.4', 'minTa': '-3.3', 'minTaHrmt': '0715', 'maxTa': '4.7', 'maxTaHrmt': '1556', 'mi10MaxRn': '', 'mi10MaxRnHrmt': '', 'hr1MaxRn ...

# %%
print(type(items))
print(len(items))
# Out:
# <class 'list'>
# 365

# %%
import pandas as pd
df = pd.DataFrame(items)

df.to_csv("asos_daily_2024", index=False)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

WEATHER_API_KEY = os.getenv("WEATHER_API_KEY")

# %%
import requests
import pandas as pd

#총 96개 지점
stn_ids = [
    "90", "93", "95", "98", "99", "100", "101", "102", "104", "105",
    "106", "108", "112", "114", "115", "119", "121", "127", "129", "130",
    "131", "133", "135", "136", "137", "138", "140", "143", "146", "152",
    "155", "156", "159", "162", "165", "168", "169", "170", "172", "174",
    "177", "184", "185", "188", "189", "192", "201", "202", "203", "211",
    "212", "216", "217", "221", "226", "232", "235", "236", "238", "239",
    "243", "244", "245", "247", "248", "251", "252", "253", "254", "255",
    "257", "258", "259", "260", "261", "262", "263", "264", "266", "268",
    "271", "272", "273", "276", "277", "278", "279", "281", "283", "284",
    "285", "288", "289", "294", "295"
]

years = [
    ("20200101", "20201231"),  # 2020년
    ("20210101", "20211231"),  # 2021년  
    ("20220101", "20221231"),  # 2022년
    ("20230101", "20231231"),  # 2023년
    ("20240101", "20241231")   # 2024년
]

url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList"

dfs = []
for start_dt, end_dt in years:
    for stn_id in stn_ids:
        params = {
            "serviceKey": WEATHER_API_KEY,
            "pageNo": "1",
            "numOfRows": "999",
            "dataType": "JSON",
            "dataCd": "ASOS",
            "dateCd": "DAY",
            "startDt": start_dt,
            "endDt": end_dt,
            "stnIds": stn_id
        }
        
        try:
            res = requests.get(url, params=params)
            response = res.json()
            
            # 안전한 데이터 추출
            if (response.get("response", {}).get("header", {}).get("resultCode") == "00" and
                "body" in response.get("response", {}) and 
                "items" in response["response"]["body"]):
                
                items = response["response"]["body"]["items"]["item"]
                
                # items 형태 정규화
                if items is None:
                    items = []
                elif isinstance(items, dict):  # 단일 딕셔너리
                    items = [items]
                elif not isinstance(items, list):  # 기타 형태
                    items = []
                
                # DataFrame 생성 (빈 리스트도 처리)
                if items:
                    df_temp = pd.DataFrame(items)
                    dfs.append(df_temp)
                    print(f"✅ {start_dt}-{end_dt} 지점{stn_id}: {len(items)}건")
                else:
                    print(f"⚠️  {start_dt}-{end_dt} 지점{stn_id}: 데이터 없음")
            else:
                # API 에러 응답
                error_msg = response.get("response", {}).get("header", {}).get("resultMsg", "Unknown")
                print(f"❌ {start_dt}-{end_dt} 지점{stn_id}: {error_msg}")
# 🚨 JSON 에러 - 지점152, 20240101
# ✅ 20240101-20241231 지점155: 366건
# ✅ 20240101-20241231 지점156: 366건
# 🚨 JSON 에러 - 지점159, 20240101
# 🚨 JSON 에러 - 지점162, 20240101
# 🚨 JSON 에러 - 지점165, 20240101
# 🚨 JSON 에러 - 지점168, 20240101
# ✅ 20240101-20241231 지점169: 366건
# 🚨 JSON 에러 - 지점170, 20240101
# ✅ 20240101-20241231 지점172: 365건
# 🚨 JSON 에러 - 지점174, 20240101
# 🚨 JSON 에러 - 지점177, 20240101
# ✅ 20240101-20241231 지점184: 366건
# ✅ 20240101-20241231 지점185: 366건
# 🚨 JSON 에러 - 지점188, 20240101
# 🚨 JSON 에러 - 지점189, 20240101
# ✅ 20240101-20241231 지점192: 366건
# 🚨 JSON 에러 - 지점201, 20240101
# ✅ 20240101-20241231 지점202: 366건
# ✅ 20240101-20241231 지점203: 366건
# 🚨 JSON 에러 - 지점211, 20240101
# 🚨 JSON 에러 - 지점212, 20240101
# 🚨 JSON 에러 - 지점216, 20240101
# 🚨 JSON 에러 - 지점217, 20240101
# ✅ 20240101-20241231 지점221: 366건
# 🚨 JSON 에러 - 지점226, 20240101
# 🚨 JSON 에러 - 지점232, 20240101
# ✅ 20240101-20241231 지점235: 366건
# 🚨 JSON 에러 - 지점236, 20240101
# 🚨 JSON 에러 - 지점238, 20240101
# ✅ 20240101-20241231 지점239: 366건
# 🚨 JSON 에러 - 지점243, 20240101
# 🚨 JSON 에러 - 지점244, 20240101
# ✅ 20240101-20241231 지점245: 366건
# 🚨 JSON 에러 - 지점247, 20240101
# ✅ 20240101-20241231 지점248: 366건
# 🚨 JSON 에러 - 지점251, 20240101
# ✅ 20240101-20241231 지점252: 366건
# 🚨 JSON 에러 - 지점253, 20240101
# 🚨 JSON 에러 - 지점254, 20240101
# 🚨 JSON 에러 - 지점255, 20240101
# ✅ 20240101-20241231 지점257: 366건
# ✅ 20240101-20241231 지점258: 366건
# 🚨 JSON 에러 - 지점259, 20240101
# ✅ 20240101-20241231 지점260: 366건
# 🚨 JSON 에러 - 지점261, 20240101
# 🚨 JSON 에러 - 지점262, 20240101
# 🚨 JSON 에러 - 지점263, 20240101
# ✅ 20240101-20241231 지점264: 366건
# ✅ 20240101-20241231 지점266: 366건
# ✅ 20240101-20241231 지점268: 366건
# 🚨 JSON 에러 - 지점271, 20240101
# ✅ 20240101-20241231 지점272: 366건
# ✅ 20240101-20241231 지점273: 366건
# 🚨 JSON 에러 - 지점276, 20240101
# ✅ 20240101-20241231 지점277: 366건
# 🚨 JSON 에러 - 지점278, 20240101
# 🚨 JSON 에러 - 지점279, 20240101
# 🚨 JSON 에러 - 지점281, 20240101
# ✅ 20240101-20241231 지점283: 366건
# 🚨 JSON 에러 - 지점284, 20240101
# ✅ 20240101-20241231 지점285: 366건
# ✅ 20240101-20241231 지점288: 366건
# 🚨 JSON 에러 - 지점289, 20240101
# 🚨 JSON 에러 - 지점294, 20240101
# 🚨 JSON 에러 - 지점295, 20240101
# 🎉 수집 완료: 155258건
